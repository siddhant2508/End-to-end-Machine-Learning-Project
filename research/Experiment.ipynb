# %%
import os

# %%
import pandas as pd

# %%
wines = pd.read_csv("WineQT.csv")
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
wines.shape
# Out:
# (1143, 13)

# %%
wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %%
wines.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: cycler>=0.10 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: pillow>=8 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
wines.hist(bins=50, figsize=(20,15), color= "orange")
plt.show()

# %%
pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Developer/CommandLineTools/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_aa0083d3720544f8a09765654e2dea37/setup.py'"'"'; __file__='"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_aa0083d3720544f8a09765654e2dea37/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-pip-egg-info-ye65qane
#          cwd: /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_aa0083d3720544f8a09765654e2dea37/
#     Complete output (15 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/1c/395a83ee7b2d2ad7a05b453872053d41449564477c81dc356f720b16eac4/sklearn-0.0.post12.tar.gz#sha256=54cff9e20839b7b202321178228af4d9388bedf78425d9299fd9ee170d68802e (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading sklearn-0.0.post11.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Developer/CommandLineTools/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_79f906089740488fa6a801bfcb094aec/setup.py'"'"'; __file__='"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_79f906089740488fa6a801bfcb094aec/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-pip-egg-info-2g6_ctid
#          cwd: /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_79f906089740488fa6a801bfcb094aec/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a4/0b/d1c703256cf293be77b7db44dbef62251fe02a97d0bef981f7120b0b0c0f/sklearn-0.0.post11.tar.gz#sha256=af035c4f0b970b7fc2d3856079aa1aa1032df3d7f65048a9d87114abf13c4629 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading sklearn-0.0.post10.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Developer/CommandLineTools/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_8c965a3339aa457191532a02efa8c818/setup.py'"'"'; __file__='"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_8c965a3339aa457191532a02efa8c818/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-pip-egg-info-5ltek4km
#          cwd: /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_8c965a3339aa457191532a02efa8c818/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b9/0e/b2a4cfaa9e12b9ca4c71507bc26d2c99d75de172c0088c9835a98cf146ff/sklearn-0.0.post10.tar.gz#sha256=d4cd5a2e64b3caaf82cd5e33c46884dfeec5ebf991710d9faeb4fe81cadb3ba6 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading sklearn-0.0.post9.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Developer/CommandLineTools/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_83872d27f3b24604939f96bd86587f1d/setup.py'"'"'; __file__='"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_83872d27f3b24604939f96bd86587f1d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-pip-egg-info-acsr66nz
#          cwd: /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_83872d27f3b24604939f96bd86587f1d/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/28/86/207a003339023247fef1bb5bc9f5093140d17294b2f6d15bfcd4885e469e/sklearn-0.0.post9.tar.gz#sha256=1ff5864cf30489ee48a014fe8f4320d7bb59592392a4ef52ae9d7a37942615ac (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading sklearn-0.0.post7.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Developer/CommandLineTools/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_2e4fd2bc77f34ed6bc76a78368d90646/setup.py'"'"'; __file__='"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_2e4fd2bc77f34ed6bc76a78368d90646/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-pip-egg-info-dgrz1bty
#          cwd: /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_2e4fd2bc77f34ed6bc76a78368d90646/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/70/ce/81aa643f3c43488c4a1e417e45f696a61e7ac82b57190fad3c310df2c07b/sklearn-0.0.post7.tar.gz#sha256=1c89020b364fdc3aa2839e0ae34e8f0b406669e4b5c2359dda3ac398f9c76874 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading sklearn-0.0.post5.tar.gz (3.7 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Developer/CommandLineTools/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_486467d8118d43149f855412d2d7a766/setup.py'"'"'; __file__='"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_486467d8118d43149f855412d2d7a766/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-pip-egg-info-th2z3f_y
#          cwd: /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_486467d8118d43149f855412d2d7a766/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/7a/93/e0e1b1e98f39dfca7ec9795cb46f6e09e88a2fd5d4a28e4b3d1f618a2aec/sklearn-0.0.post5.tar.gz#sha256=7377c714a03a79bbe9196f435db931fd2a6fa8c68514da7ed3a251fd08c52e2c (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading sklearn-0.0.post4.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Developer/CommandLineTools/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_81c2cd82e4e9463ba5429b7bba3d816a/setup.py'"'"'; __file__='"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_81c2cd82e4e9463ba5429b7bba3d816a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-pip-egg-info-_ykcv4qq
#          cwd: /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_81c2cd82e4e9463ba5429b7bba3d816a/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/99/b2/165110013aa66fae6fc13918ad0e9de4801e5f1691d371bf8b63328037e6/sklearn-0.0.post4.tar.gz#sha256=0e81ec9c32d4bb418e7be8f1ec1027d174975502dc84cbc4f4564b4cba31e674 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Developer/CommandLineTools/usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_9f84238e6e3a4967877c5d0e3ed695ca/setup.py'"'"'; __file__='"'"'/private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_9f84238e6e3a4967877c5d0e3ed695ca/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-pip-egg-info-d7cqkdgt
#          cwd: /private/var/folders/cz/dms2fb5s2x10f399t8jfwgwr0000gn/T/pip-install-sh0z9mnp/sklearn_9f84238e6e3a4967877c5d0e3ed695ca/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/db/1e/af4e9cded5093a92e60d4ae7149a02c7427661b2db66c8ea4d34b17864a2/sklearn-0.0.post1.tar.gz#sha256=76b9ed1623775168657b86b5fe966d45752e5c87f528de6240c38923b94147c5 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 2.2 MB/s eta 0:00:01
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 50.1 MB/s eta 0:00:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 50.5 MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Users/siddhantdhatrak/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sklearn) (2.0.2)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=431520b1300f1592ca764e323db205918f736f3af7fbcce97253813206d916e5
#   Stored in directory: /Users/siddhantdhatrak/Library/Caches/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.13.1 sklearn-0.0 threadpoolctl-3.6.0
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
X = wines.drop(["quality"], axis=1)
Y = wines["quality"]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol    Id
# 0         9.4     0
# 1         9.8     1
# 2         9.8     2
# 3         9.8     3
# 4         9.4     4
# ...       ...   ...
# 1138     11.0  1592
# 1139      9.5  1593
# 1140     10.5  1594
# 1141     11.2  1595
# 1142     10.2  1597
#
# [1143 rows x 12 columns]

# %%
Y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
X_train , X_test , Y_train, Y_test = train_test_split(X,Y, test_size=0.2,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (914, 12)
# (229, 12)
# (914,)
# (229,)

# %%
from sklearn.linear_model import ElasticNet

# %%
lr = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state= 42)
lr.fit(X_train,Y_train)
# Out:
# ElasticNet(alpha=0.1, random_state=42)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import numpy as np

# %%
def eval_metrics(actual,pred):
    rmse= np.sqrt(mean_squared_error(actual,pred))
    mae= mean_absolute_error(actual,pred)
    r2=r2_score(actual,pred)

    return rmse, mae, r2

# %%
predicted_value=lr.predict(X_test)

# %%
predicted_value
# Out:
# array([5.41827018, 5.11124249, 5.47220991, 5.27146275, 6.35194597,
#        6.49994323, 5.41305884, 5.19195673, 5.70485351, 5.3980524 ,
#        6.27045638, 5.92748989, 5.74737186, 6.14964586, 5.85425439,
#        5.56051331, 5.5014995 , 5.67549416, 5.42078388, 6.20175259,
#        5.74908949, 5.88520389, 5.21947575, 6.15249646, 5.6468529 ,
#        5.41428448, 6.3145176 , 5.86278447, 5.35666361, 5.57796355,
#        6.39874219, 5.54267933, 6.4496524 , 5.67001657, 5.75237299,
#        5.26007007, 5.67783963, 5.80701407, 6.5990968 , 5.14814451,
#        5.98899061, 5.67122952, 6.68134479, 5.48775059, 5.42112696,
#        5.37167409, 5.91657362, 5.90908389, 5.1220525 , 5.88900446,
#        6.21305379, 5.61952411, 5.61123571, 5.699142  , 5.51902632,
#        6.23358344, 5.74317845, 5.75628747, 5.51127107, 5.42736815,
#        5.51287797, 5.98921461, 5.72192076, 5.9337469 , 6.02348539,
#        5.59003484, 6.52929783, 5.21137133, 5.18590923, 5.97240397,
#        5.34815543, 5.36882586, 5.31793627, 6.19542595, 5.55907177,
#        5.4036401 , 5.71112085, 5.54685762, 5.41246078, 5.38726762,
#        5.54882012, 5.62567429, 5.70565072, 5.571396  , 5.43979413,
#        6.06509059, 6.04282912, 5.67111469, 6.07894256, 5.35529655,
#        5.88852596, 5.79225381, 5.1890951 , 5.13731836, 5.32899372,
#        5.119138  , 5.25211072, 5.70515843, 6.2425237 , 5.61234263,
#        5.66527717, 6.28472763, 5.4719175 , 6.01136684, 5.39178437,
#        5.20790463, 5.68706371, 6.02591832, 5.79894489, 5.96921023,
#        5.77546638, 5.3132684 , 5.60211967, 5.68856933, 5.04192156,
#        5.34111659, 5.60304652, 6.75671008, 5.88478675, 5.54385976,
#        5.24327836, 5.23052308, 5.44486339, 5.24384984, 5.44158619,
#        5.61039907, 5.7245807 , 5.93800696, 5.30755689, 6.4973739 ,
#        5.1948979 , 5.4833801 , 5.41846654, 5.57946702, 7.2946505 ,
#        5.63744915, 5.02630961, 5.36564682, 5.76006608, 5.66579519,
#        6.67028708, 5.77532963, 5.5107956 , 5.06656083, 6.31856464,
#        5.19979507, 4.99082425, 5.45907938, 5.15543808, 5.07308907,
#        5.90904085, 5.30486874, 5.77448175, 5.4060017 , 5.69664537,
#        5.83728506, 5.45900915, 5.46371968, 6.23226228, 5.63407496,
#        6.18396278, 5.36487391, 5.805405  , 5.77213507, 6.28249562,
#        5.30953484, 5.80993324, 5.9706044 , 5.51712327, 5.20143333,
#        6.31852509, 5.38264483, 5.29538154, 5.63067509, 5.2525635 ,
#        5.23343374, 5.93768921, 5.75634606, 5.74318354, 5.62555906,
#        5.67194015, 5.59214039, 5.77056394, 5.36381605, 5.10644418,
#        5.09313618, 5.84190213, 5.1640059 , 5.73489722, 5.73086841,
#        5.70876769, 5.57867849, 6.31923718, 5.59076509, 5.63021121,
#        5.37729999, 5.3272151 , 6.35296382, 6.10469755, 6.00005754,
#        6.02316971, 5.766937  , 5.26560723, 5.59070571, 5.66372338,
#        5.69721191, 5.21335321, 5.29016933, 5.9844589 , 5.66129278,
#        5.32086762, 6.01193564, 5.27453584, 5.93817779, 5.46177728,
#        5.25591996, 6.60105335, 5.26125275, 6.20418518, 5.53289748,
#        6.307383  , 5.2679819 , 5.54682209, 5.81580378, 5.60362956,
#        6.1035357 , 5.76621347, 5.34768236, 5.63550159])

# %%
(rmse, mae,r2) =eval_metrics(Y_test,predicted_value)

# %%
print("rmse=",rmse)
print("mae=",mae)
print("r2=",r2)
# Out:
# rmse= 0.629995959330732
# mae= 0.5034416470825984
# r2= 0.2867669826959264
